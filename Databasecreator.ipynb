# %% [markdown]
# # DatabaseCreator

# %%
# %timeit

from langchain_community.document_loaders import DirectoryLoader
#from langchain.text_splitter import  RecursiveCharacterTextSplitter
from langchain.text_splitter import  MarkdownTextSplitter
from langchain.schema import Document

from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
DATA_PATH = r'/kaggle/input/books-md/data'
loader = DirectoryLoader(DATA_PATH,glob='*.md')
documents = loader.load()


text_splitter = MarkdownTextSplitter(chunk_size=1000,chunk_overlap=100)

chunks = text_splitter.split_documents(documents)

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
modelPath = "sentence-transformers/all-MiniLM-l6-v2"
# Create a dictionary with model configuration options, specifying to use the CPU for computations
model_kwargs = {'device':'cpu'}
# Create a dictionary with encoding options, specifically setting 'normalize_embeddings' to False
encode_kwargs = {'normalize_embeddings': False}
# Initialize an instance of HuggingFaceEmbeddings with the specified parameters
embeddings = HuggingFaceEmbeddings(
    model_name=modelPath,     # Provide the pre-trained model's path
    model_kwargs=model_kwargs, # Pass the model configuration options
    encode_kwargs=encode_kwargs # Pass the encoding options
     )

# %%
db = FAISS.load_local("faiss_index", embeddings)

# %%
query = "what is the problem ? "

# %%
docs = db.similarity_search(query)

# %%
print(f"Split {len(documents)} documents into {len(chunks)} chunks.")
# Out:
# Split 21 documents into 9801 chunks.

# %%
doc = chunks[1000]
doc.metadata
# Out:
# {'source': '/kaggle/input/books-md/data/LAWS OF HUMAN NATURE RG.md'}

# %%
doc = chunks[1800]
doc.metadata
# Out:
# {'source': '/kaggle/input/books-md/data/12 RULES FOR LIFE.md'}

# %%
doc = chunks[2800]
doc.metadata
# Out:
# {'source': '/kaggle/input/books-md/data/MASTERY RG.md'}

# %%
doc = chunks[3800]
doc.metadata
# Out:
# {'source': '/kaggle/input/books-md/data/DAILY STOOIC RH.md'}

# %%
# Define the path to the pre-trained model you want to use
modelPath = "sentence-transformers/all-MiniLM-l6-v2"

# Create a dictionary with model configuration options, specifying to use the CPU for computations
model_kwargs = {'device':'cuda'}

# Create a dictionary with encoding options, specifically setting 'normalize_embeddings' to False
encode_kwargs = {'normalize_embeddings': False}

# Initialize an instance of HuggingFaceEmbeddings with the specified parameters
embeddings = HuggingFaceEmbeddings(
    model_name=modelPath,     # Provide the pre-trained model's path
    model_kwargs=model_kwargs, # Pass the model configuration options
    encode_kwargs=encode_kwargs # Pass the encoding options
)

# %%
db = FAISS.from_documents(chunks, embeddings)
db.save_local("faiss_index")

# %%
db.save_local("faiss_index")
